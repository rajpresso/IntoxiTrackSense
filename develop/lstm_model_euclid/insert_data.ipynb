# %%
# %cd /home/alpaco/project/drunk_prj/models/rsj_model_euclid
# !./run_all.shc
# Out:
# /home/alpaco/project/drunk_prj/models/rsj_model_euclid
# /bin/bash: ./run_all.shc: No such file or directory

# %%
# !./run_all.sh train
# Out:
# Checking config/config.py...
# config/config.py is valid.
# Running util/util.py...
# Running util.util...
# util.util executed successfully.
# Running model/lstm_model.py...
# Running model.lstm_model...
# /home/alpaco/anaconda3/envs/rsj-01/lib/python3.9/runpy.py:127: RuntimeWarning: 'model.lstm_model' found in sys.modules after import of package 'model', but prior to execution of 'model.lstm_model'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# model.lstm_model executed successfully.
# Running train.py...
# Data path: /home/alpaco/project/drunk_prj/models/rsj_model_euclid/testdata/618-8_cam01_drunken01_place03_night_spring_4102_4957_totter.csv
# center_node
# transform_keypoints
# create_sequences
# Coordinate columns: ['xm', 'ym', 'm1', 's1', 'm2', 's2', 'm3', 's3', 'm4', 's4', 'm5', 's5', 'm6', 's6', 'm7', 's7', 'm8', 's8', 'm9', 's9', 'm10', 's10', 'm11', 's11', 'm12', 's12', 'm13', 's13', 'm14', 's14', 'm15', 's15', 'm16', 's16', 'm17', 's17', 'y']
# ...

# %%
# !python /home/alpaco/project/drunk_prj/models/rsj_model_euclid/util/data_import.py

# %%
from  util.def_data_insert_table import insert_data
folder_path = "/home/alpaco/project/drunk_prj/data/normal_0넣기"
version = '2.0'
major_category = 'normal'
sub_category ='nr'

insert_data(folder_path , version, major_category, sub_category)
# Out:
# file_name C_32_7_smp_su_09-11_11-01-00_c_for_DF2_(53_143) major_category normal
# File 'C_32_7_smp_su_09-11_11-01-00_c_for_DF2_(53_143).csv' successfully stored in the database.
# file_name C_32_10_smp_su_09-11_13-47-00_c_aft_DF2_(54_144) major_category normal
# File 'C_32_10_smp_su_09-11_13-47-00_c_aft_DF2_(54_144).csv' successfully stored in the database.
# file_name C_32_8_smp_su_09-11_11-17-00_c_for_DF2_(56_146) major_category normal
# File 'C_32_8_smp_su_09-11_11-17-00_c_for_DF2_(56_146).csv' successfully stored in the database.
# file_name C_32_9_smp_su_09-11_12-48-00_b_aft_DF2_(57_147) major_category normal
# File 'C_32_9_smp_su_09-11_12-48-00_b_aft_DF2_(57_147).csv' successfully stored in the database.
# file_name C_32_7_smp_su_09-11_10-41-00_c_for_DF2_(55_145) major_category normal
# File 'C_32_7_smp_su_09-11_10-41-00_c_for_DF2_(55_145).csv' successfully stored in the database.
# file_name C_32_7_smp_su_09-11_10-44-00_a_for_DF2_(52_142) major_category normal
# ...

# %%
from  util.def_data_insert_table import insert_data
folder_path = "/home/alpaco/project/drunk_prj/data/croki_0넣기"
version = '2.0'
major_category = 'croki'
sub_category ='cr'

insert_data(folder_path , version, major_category, sub_category)
# Out:
# file_name 209-5_cam02_drunken01_place03_night_spring_5038_6650_totter_(356_1256) major_category croki
# File '209-5_cam02_drunken01_place03_night_spring_5038_6650_totter_(356_1256).csv' successfully stored in the database.
# file_name 278-4_cam01_drunken03_place03_night_winter_479_1427_totter_(24_924) major_category croki
# File '278-4_cam01_drunken03_place03_night_winter_479_1427_totter_(24_924).csv' successfully stored in the database.
# file_name 233-2_cam01_drunken03_place02_night_spring_7893_9008_totter_(107_1007) major_category croki
# File '233-2_cam01_drunken03_place02_night_spring_7893_9008_totter_(107_1007).csv' successfully stored in the database.
# file_name 217-2_cam03_drunken04_place03_night_summer_155_1916_totter_(430_1330) major_category croki
# File '217-2_cam03_drunken04_place03_night_summer_155_1916_totter_(430_1330).csv' successfully stored in the database.
# file_name 278-4_cam02_drunken03_place03_night_winter_1597_3116_totter_(309_1209) major_category croki
# ...

# %%
from  util.def_data_insert_table import insert_data
folder_path = "/home/alpaco/project/drunk_prj/data/test_0넣기3"
version = 'test2.0'
category = 'test'
sub_category ='test_0넣기3'

insert_data(folder_path , version, category, sub_category)

# %%
from  util.def_data_insert_table import insert_data
folder_path = '/home/alpaco/project/drunk_prj/data/abs_test_0넣기3'
version = 'test3.0'
category = 'test'
sub_category ='abs_test_0넣기3'

insert_data(folder_path , version, category, sub_category)
# Out:
# file_name 617-2_cam02_drunken04_place03_night_spring_717_2898_totter_(640_1540) major_category test
# File '617-2_cam02_drunken04_place03_night_spring_717_2898_totter_(640_1540).csv' successfully stored in the database.
# file_name 617-6_cam01_drunken04_place03_night_summer_4909_6240_totter_(215_1115) major_category test
# File '617-6_cam01_drunken04_place03_night_summer_4909_6240_totter_(215_1115).csv' successfully stored in the database.
# file_name 618-3_cam01_drunken04_place03_night_spring_1930_3718_totter_(444_1344) major_category test
# File '618-3_cam01_drunken04_place03_night_spring_1930_3718_totter_(444_1344).csv' successfully stored in the database.
# file_name 618-1_cam01_drunken04_place03_night_spring_2463_3550_totter_(93_993) major_category test
# File '618-1_cam01_drunken04_place03_night_spring_2463_3550_totter_(93_993).csv' successfully stored in the database.
# file_name 616-6_cam02_drunken03_place01_day_spring_135_1644_totter_(304_1204) major_category test
# ...

# %%
# /home/alpaco/project/drunk_prj/data/normal_editted_Final

from  util.def_data_insert_table import insert_data
folder_path = "/home/alpaco/project/drunk_prj/data/normal_editted_Final"
version = '3.0'
major_category = 'normal'
sub_category ='normal_editted_Final'

insert_data(folder_path , version, major_category, sub_category)
# Out:
# file_name C_32_8_smp_su_09-11_11-43-00_b_for_DF2_label1 major_category normal
# File 'C_32_8_smp_su_09-11_11-43-00_b_for_DF2_label1.csv' successfully stored in the database.
# file_name C_32_10_smp_su_09-11_14-08-00_a_aft_DF2_labelID: 2425.0 major_category normal
# File 'C_32_10_smp_su_09-11_14-08-00_a_aft_DF2_labelID: 2425.0.csv' successfully stored in the database.
# file_name C_32_7_smp_su_09-11_10-42-00_a_for_DF2_label2 major_category normal
# File 'C_32_7_smp_su_09-11_10-42-00_a_for_DF2_label2.csv' successfully stored in the database.
# file_name C_32_11_smp_su_09-11_15-06-00_b_aft_DF2_label3 major_category normal
# File 'C_32_11_smp_su_09-11_15-06-00_b_aft_DF2_label3.csv' successfully stored in the database.
# file_name C_32_11_smp_su_09-11_15-11-00_c_aft_DF2_label3 major_category normal
# File 'C_32_11_smp_su_09-11_15-11-00_c_aft_DF2_label3.csv' successfully stored in the database.
# file_name C_32_11_smp_su_09-11_14-59-00_c_aft_DF2_label2 major_category normal
# ...
